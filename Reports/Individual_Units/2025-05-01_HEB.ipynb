# %% [markdown]
# # 2025-05-01, Link Checker Report for HEB

# %%
# Import Packages
import pandas as pd
import sqlite3
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
UNIT_FILTER = "HEB"  # Example: "MUS", "BEINECKE", or None

# %%
# Connect to Database
conn = sqlite3.connect("/Users/if224/Documents/rds_git_repos/link_checker/link_checker.db")
print(f"Database connected")

# %% [markdown]
# # Overview

# %%
# Summary Stats for Selected Unit

params = []
summary_query = """
SELECT 
    COUNT(*) AS Total_Links,
    SUM(CASE WHEN Status != '200' THEN 1 ELSE 0 END) AS Total_Errors
FROM (
    SELECT 
        bibid,
        url,
        Unit,
        Status,
        ROW_NUMBER() OVER (
            PARTITION BY bibid, url
            ORDER BY check_date DESC
        ) AS rn
    FROM bib_url_status_report
)
WHERE rn = 1 AND Unit = ?;
"""

summary_df = pd.read_sql_query(summary_query, conn, params=[UNIT_FILTER])


# Calculate error rate
totals = summary_df.iloc[0]
total_links = totals['Total_Links']
total_errors = totals['Total_Errors']
total_success = total_links - total_errors
error_rate = (total_errors / total_links) * 100 if total_links else 0

# Print summary
(f"""
### Summary for Unit: `{UNIT_FILTER or 'All Units'}`

- **Total Links Checked**: {total_links}
- **Total Errors**: {total_errors}
- **Successful Links**: {total_success}
- **Error Rate**: {error_rate:.2f}%
""")

# %% [markdown]
# ### Summary for Unit: `HEB`
#
# - Total Links Checked: 648
# - Total Errors: 289
# - Successful Links: 359
# - Error Rate: 44.60%

# %%
'\n### Summary for Unit: `HEB`\n\n- **Total Links Checked**: 648\n- **Total Errors**: 289\n- **Successful Links**: 359\n- **Error Rate**: 44.60%\n'

# %% [markdown]
# # Links and Errors by Domain

# %%
params = []
query = """
SELECT Domain, Status, COUNT(*) AS Error_Count
FROM bib_url_status_report
"""

if UNIT_FILTER:
    query += "WHERE Unit = ? AND Status != '200'\n"
    params.append(UNIT_FILTER)
else:
    query += "WHERE Status != '200'\n"

query += "GROUP BY Domain, Status ORDER BY Error_Count DESC"

# Query the data
domain_error_types = pd.read_sql_query(query, conn, params=params)
domain_error_types
# Out:
#                                       Domain  \
# 0                  www.yiddishbookcenter.org
# 1                            yizkor.nypl.org
# 2                            yizkor.nypl.org
# 3                            www.archive.org
# 4                  www.yiddishbookcenter.org
# 5                        www.hebrewbooks.org
# 6                        www.hebrewbooks.org
# 7                             web.nli.org.il
# 8                  beinecke.library.yale.edu
# 9                             www.cbs.gov.il
# 10  library.osu.edu.proxy.lib.ohio-state.edu
# 11                              www.imdb.com
# 12                            ledorot.gov.il
# 13                            web.nli.org.il
# 14                         www.jpress.org.il
# 15                            hdl.handle.net
# 16                             www.jstor.org
# 17                             www.jstor.org
# 18                          bibpurl.oclc.org
# 19                    catalog.hathitrust.org
# 20                           digital.cjh.org
# 21                  digital.library.yale.edu
# 22               eu01.alma.exlibrisgroup.com
# 23                            ledorot.gov.il
# 24                     libraries.indiana.edu
# 25                     libraries.indiana.edu
# 26                              muse.jhu.edu
# 27                         primage.tau.ac.il
# 28                     reshit.hartman.org.il
# 29                           www.btselem.org
# 30                            www.cbs.gov.il
# 31                       www.hebrewbooks.org
# 32                 www.yiddishbookcenter.org
# 33                          bibpurl.oclc.org
# 34                          bibpurl.oclc.org
# 35                          books.google.com
# 36                       digital.casalini.it
# 37                  digital.library.yale.edu
# 38               eu01.alma.exlibrisgroup.com
# 39                            hdl.handle.net
# 40                     hdl.library.upenn.edu
# 41                           library.osu.edu
# 42                          nbn-resolving.de
# 43                           openlibrary.org
# 44                         primage.tau.ac.il
# 45                     reshit.hartman.org.il
# 46                           web.archive.org
# 47                www.bet-alpha-editions.com
# 48                www.bet-alpha-editions.com
# 49                www.bet-alpha-editions.com
# 50                         www.degruyter.com
# 51                         www.jpress.org.il
# 52                             www.jstor.org
# 53                            www.nli.org.il
# 54                           yizkor.nypl.org
#
#                                                Status  Error_Count
# 0              {"requests": "403", "selenium": "403"}          412
# 1              {"requests": "404", "selenium": "404"}          130
# 2                                                 404           67
# 3   Exception: <class 'selenium.common.exceptions....           57
# 4                                                 403           33
# 5                                                 403           30
# 6              {"requests": "403", "selenium": "403"}           24
# 7              {"requests": "403", "selenium": "403"}            8
# 8   Exception: <class 'selenium.common.exceptions....            7
# 9   Exception: <class 'selenium.common.exceptions....            7
# 10                                     unknown_status            6
# 11                                                403            5
# 12           {"requests": "None", "selenium": "None"}            4
# 13                                                403            4
# 14             {"requests": "403", "selenium": "403"}            4
# 15  Exception: <class 'selenium.common.exceptions....            3
# 16                                                403            3
# 17             {"requests": "403", "selenium": "403"}            3
# 18             {"requests": "403", "selenium": "403"}            2
# 19  Exception: <class 'selenium.common.exceptions....            2
# 20  Exception: <class 'selenium.common.exceptions....            2
# 21             {"requests": "404", "selenium": "404"}            2
# 22             {"requests": "403", "selenium": "403"}            2
# 23  Exception: <class 'selenium.common.exceptions....            2
# 24                                                403            2
# 25             {"requests": "403", "selenium": "403"}            2
# 26  Exception: <class 'selenium.common.exceptions....            2
# 27           {"requests": "None", "selenium": "None"}            2
# 28             {"requests": "403", "selenium": "403"}            2
# 29             {"requests": "429", "selenium": "429"}            2
# 30  Exception: <class 'selenium.common.exceptions....            2
# 31  Exception: <class 'selenium.common.exceptions....            2
# 32  Exception: <class 'selenium.common.exceptions....            2
# 33                                                403            1
# 34  Exception: <class 'selenium.common.exceptions....            1
# 35  Exception: <class 'selenium.common.exceptions....            1
# 36                                                502            1
# 37                                                404            1
# 38                                                403            1
# 39                                     unknown_status            1
# 40  Exception: <class 'selenium.common.exceptions....            1
# 41  Exception: <class 'selenium.common.exceptions....            1
# 42  Exception: <class 'selenium.common.exceptions....            1
# 43  Exception: <class 'selenium.common.exceptions....            1
# 44  Exception: <class 'urllib3.exceptions.ReadTime...            1
# 45                                                403            1
# 46  Exception: <class 'urllib3.exceptions.ReadTime...            1
# 47                                                403            1
# 48             {"requests": "403", "selenium": "403"}            1
# 49             {"requests": "403", "selenium": "404"}            1
# 50                                                202            1
# 51                                                403            1
# 52            {"requests": "403", "selenium": "None"}            1
# 53            {"requests": "520", "selenium": "None"}            1
# 54  Exception: <class 'selenium.common.exceptions....            1

# %%
# Format the output filename
today = datetime.today().strftime("%Y-%m-%d")
filename = f"{UNIT_FILTER}_linkerrors_{today}.csv"

# Build the query
# query = """
# SELECT *
# FROM bib_url_status_report
# WHERE Status != '200' AND Unit = ?
# """
query = """
SELECT 
    *
FROM (
    SELECT 
        ROW_NUMBER() OVER (
            PARTITION BY 
                bibID, URL, Unit
            ORDER BY 
                Check_Date DESC
        ) as rn,
        ID, 
        Unit, 
        BibID, 
        URL, 
        Status_Requests,
        Status_Selenium, 
        Error_Requests,
        Error_Selenium,
        Check_Date
    FROM 
        url_status_report
) 
WHERE 
    rn = 1 
AND 
    ( Status_Requests < 200 OR Status_Requests > 299 OR Status_Requests IS NULL )
AND 
    ( Status_Selenium < 200 OR Status_Selenium > 299 OR Status_Selenium IS NULL ) 
AND 
    Unit = ?
"""

# Run the query
error_links_df = pd.read_sql_query(query, conn, params=[UNIT_FILTER])

# Export to CSV
error_links_df.to_csv(filename, index=False,columns= [
    "Unit", 
    "BibID", 
    "URL", 
    "Status_Requests",
    "Status_Selenium", 
    "Error_Requests",
    "Error_Selenium",
    "Check_Date" 
    ])

# print(f"Saved error links to: {filename}")
error_links_df
# Out:
#      rn      ID Unit     BibID  \
# 0     1  257251  HEB    957687
# 1     1  257252  HEB   1010822
# 2     1  257253  HEB   1010824
# 3     1  257254  HEB   1013941
# 4     1  257255  HEB   1026522
# ..   ..     ...  ...       ...
# 287   1  257539  HEB  16046097
# 288   1  257540  HEB  16088777
# 289   1  257541  HEB  16212276
# 290   1  257542  HEB  16397286
# 291   1  257543  HEB  16397962
#
#                                                    URL  Status_Requests  \
# 0        http://www.yiddishbookcenter.org/books/browse            403.0
# 1        http://www.yiddishbookcenter.org/books/browse            403.0
# 2        http://www.yiddishbookcenter.org/books/browse            403.0
# 3        http://www.yiddishbookcenter.org/books/browse            403.0
# 4        http://www.yiddishbookcenter.org/books/browse            403.0
# ..                                                 ...              ...
# 287  https://www.yiddishbookcenter.org/collections/...            403.0
# 288  http://www.yiddishbookcenter.org/collections/y...            403.0
# 289  http://www.yiddishbookcenter.org/collections/y...            403.0
# 290  https://www.yiddishbookcenter.org/collections/...            403.0
# 291  https://www.yiddishbookcenter.org/collections/...            403.0
#
#     Status_Selenium Error_Requests Error_Selenium                  Check_Date
# 0               403           None           None  2025-04-16 16:12:36.711612
# 1               403           None           None  2025-04-16 16:12:36.711612
# 2               403           None           None  2025-04-16 16:12:36.711612
# 3               403           None           None  2025-04-16 16:12:36.711612
# 4               403           None           None  2025-04-16 16:12:36.711612
# ..              ...            ...            ...                         ...
# 287             403           None           None  2025-04-16 16:12:36.711612
# 288             403           None           None  2025-04-16 16:12:36.711612
# 289             403           None           None  2025-04-16 16:12:36.711612
# 290             403           None           None  2025-04-16 16:12:36.711612
# 291             403           None           None  2025-04-16 16:12:36.711612
#
# [292 rows x 10 columns]
